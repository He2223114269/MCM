# %%
pip install openpyxl
# Out:
# ...
#      ------------------------------------ 250.0/250.0 kB 140.8 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
x = np.arange(2000,2018)
x
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017])

# %%
data = pd.read_excel("D:\codaworksplce\python_work\Mathematical_Modeling\My_code\数据预处理\九省\浙江\能源结构\能源规划\浙江省按行业分国有经济能源工业固定资产投资.xlsx")
data = data.T
# 将第一行设置为表头  
data.columns = data.iloc[0]  
# 删除原始的第一行（表头）  
data = data.drop(["指标","2020年","2019年"])
data = data.drop('数据来源：国家统计局', axis=1)
data
# Out:
# 指标    国有经济能源工业固定资产投资(亿元) 国有经济煤炭采选业固定资产投资(亿元) 国有经济石油和天然气开采业固定资产投资(亿元)  \
# 2018年
# 2017年                416
# 2016年              419.4
# 2015年                509
# 2014年             528.56
# 2013年             458.93
# 2012年             432.55
# 2011年                420
# 2010年              325.6
# 2009年             317.88
# 2008年             258.46
# 2007年             338.97
# 2006年             271.56
# 2005年             291.11
# 2004年              199.3
# 2003年             108.66                0.21
# 2002年              83.31
# 2001年              90.51
# 2000年              91.08
#
# 指标    国有经济电力、蒸汽、热水生产和供应业固定资产投资(亿元) 国有经济石油加工及炼焦业固定资产投资(亿元)  \
# 2018年
# 2017年                          403                   0.12
# 2016年                       387.79                   1.54
# 2015年                          482
# 2014年                       493.72                   7.55
# 2013年                       411.05                   6.09
# 2012年                       403.49                   0.11
# ...

# %%
df = data.fillna(0)
