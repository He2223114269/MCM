# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']

# %% [markdown]
# # 绿色金融

# %%
# green_en = pd.read_excel("2010-2020长江经济带绿色金融指数.xlsx")
green_en = pd.read_excel("绿色金融.xlsx",sheet_name = "绿色金融发展指数")
# green_en = pd.read_excel("绿色金融发展指数.xlsx",sheet_name = "综合评分")
green_en
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16996\380493102.py in <module>
#       1 # green_en = pd.read_excel("2010-2020长江经济带绿色金融指数.xlsx")
# ----> 2 green_en = pd.read_excel("绿色金融.xlsx",sheet_name = "绿色金融发展指数")
#       3 # green_en = pd.read_excel("绿色金融发展指数.xlsx",sheet_name = "综合评分")
#       4 green_en
#
# c:\users\22231\appdata\local\programs\python\python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\users\22231\appdata\local\programs\python\python37\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# c:\users\22231\appdata\local\programs\python\python37\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1190             else:
#    1191                 ext = inspect_excel_format(
# -> 1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#    1194                 if ext is None:
#
# c:\users\22231\appdata\local\programs\python\python37\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(content_or_path, storage_options)
#    1069
#    1070     with get_handle(
# -> 1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#    1073         stream = handle.handle
#
# c:\users\22231\appdata\local\programs\python\python37\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '绿色金融.xlsx'

# %%
green_en_ =  pd.DataFrame() 
green_en_["年份"] = green_en["绿色金融发展指数"]
green_en_["上游地区"] = green_en["重庆市"] +green_en["四川省"] + green_en["贵州省"] + green_en["云南省"]
green_en_["中游地区"] = green_en["安徽省"] +green_en["江西省"] + green_en["湖北省"]
green_en_["下游地区"] = green_en["上海市"] +green_en["江苏省"] + green_en["浙江省"]

# %%
green_en_.to_excel("data.xlsx")
green_en_

# %%
(0.425016-0.227249)/0.227249
# Out:
# 0.8702656557344587

# %%
names = green_en.columns
names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16996\996141074.py in <module>
# ----> 1 names = green_en.columns
#       2 names
#
# NameError: name 'green_en' is not defined

# %%
import matplotlib.pyplot as plt  
import colorsys  

# Generate a list of color codes  
num_colors = len(names)  
colors = ["#FF0000", "#00FF00", "#0000FF", "#FFFF00",   "#00FFFF", "#FF00FF","#FFA500", "#800080",  "#A52A2A", "#808080","#000000", "#FFFFA"]
plt.figure(figsize=(12, 4))  
for i in range(1, len(names)): 
    color = colors[i-1]  
    plt.plot(green_en["绿色金融发展指数"], green_en[names[i]], label=names[i], color=color)  
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Position the legend outside the plot  
plt.title('Green Finance Development Index Over Time')  
plt.xlabel('Year')  
plt.ylabel('Green Finance Development Index')  
plt.tight_layout()  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16996\2005086284.py in <module>
#       3
#       4 # Generate a list of color codes
# ----> 5 num_colors = len(names)
#       6 colors = ["#FF0000", "#00FF00", "#0000FF", "#FFFF00",   "#00FFFF", "#FF00FF","#FFA500", "#800080",  "#A52A2A", "#808080","#000000", "#FFFFA"]
#       7 plt.figure(figsize=(12, 4))
#
# NameError: name 'names' is not defined

# %%
import matplotlib.pyplot as plt  
import colorsys  

# Generate a list of color codes  
parts = green_en_.columns
plt.figure(figsize=(12, 4))  
for i in range(1, len(parts)): 
    plt.plot(green_en_["年份"], green_en_[parts[i]], label=parts[i])  
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Position the legend outside the plot  
plt.title('Green Finance Development Index Over Time')  
plt.xlabel('Year')  
plt.ylabel('Green Finance Development Index')  
plt.tight_layout()  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16996\169506111.py in <module>
#       3
#       4 # Generate a list of color codes
# ----> 5 parts = green_en_.columns
#       6 plt.figure(figsize=(12, 4))
#       7 for i in range(1, len(parts)):
#
# NameError: name 'green_en_' is not defined

# %%
from pyecharts import options as opts
from pyecharts.charts import Line
from pyecharts.commons.utils import JsCode
import pandas as pd
colors = ["#FF0000", "#00FF00", "#0000FF", "#FFFF00",   "#00FFFF", "#FF00FF","#FFA500", "#800080",  "#A52A2A", "#808080","#000000", "#FFFFA"]

# 创建折线图
line = Line().add_xaxis(green_en["绿色金融发展指数"])

# 添加数据
for i in range(1,12):
    color = colors[i-1]
    name = names[i]
    line.add_yaxis(
        series_name = name,
        y_axis = list(green_en[name]),
        label_opts=opts.LabelOpts(is_show=False),
        yaxis_index=0,
        linestyle_opts=opts.LineStyleOpts(color=color),  # Specify line color using linestyle_opts
        is_smooth=True,
    )  
line.set_global_opts(
    title_opts=opts.TitleOpts(title="Green Finance Development Index Over Time",pos_top='top', pos_left='center'),
    tooltip_opts=opts.TooltipOpts(trigger="axis"),
    xaxis_opts=opts.AxisOpts(name="Year", boundary_gap=False,min_=2010,max_=2020),
    yaxis_opts=opts.AxisOpts(name="Green Finance Development Index",type_="value",
#         axistick_opts=opts.AxisTickOpts(is_show=True),
#         splitline_opts=opts.SplitLineOpts(is_show=True),
                            ),
    legend_opts=opts.LegendOpts(pos_top="40"),# Position the legend outside the plot
)

line.render("green_finance_index.html")
line.render_notebook()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16996\188380501.py in <module>
#       6
#       7 # 创建折线图
# ----> 8 line = Line().add_xaxis(green_en["绿色金融发展指数"])
#       9
#      10 # 添加数据
#
# NameError: name 'green_en' is not defined

# %%
from pyecharts import options as opts
from pyecharts.charts import Line
from pyecharts.commons.utils import JsCode
import pandas as pd
colors = ["#FF0000", "#00FF00", "#0000FF", "#FFFF00",   "#00FFFF", "#FF00FF","#FFA500", "#800080",  "#A52A2A", "#808080","#000000", "#FFFFA"]

# 创建折线图
line = Line().add_xaxis(green_en["绿色金融发展指数"])

# 添加数据
for i in range(1,12):
    name = names[i]
    color = colors[i-1]
    line.add_yaxis(
        series_name = name,
        y_axis = list(green_en[name]),
        label_opts=opts.LabelOpts(is_show=False),
        yaxis_index=0,
        linestyle_opts=opts.LineStyleOpts(color=color),  # Specify line color using linestyle_opts
        is_smooth=False,
    )  
line.set_global_opts(
    title_opts=opts.TitleOpts(title="Green Finance Development Index Over Time",pos_top='top', pos_left='center'),
    tooltip_opts=opts.TooltipOpts(trigger="axis"),
    xaxis_opts=opts.AxisOpts(name="Year", boundary_gap=False,min_=2010,max_=2020),
    yaxis_opts=opts.AxisOpts(name="Green Finance Development Index",type_="value",
#         axistick_opts=opts.AxisTickOpts(is_show=True),
#         splitline_opts=opts.SplitLineOpts(is_show=True),
                            ),
    legend_opts=opts.LegendOpts(pos_top="40"),# Position the legend outside the plot
)

line.render("green_finance_index.html2")
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ebe46b2bcb2e4b7eb0300de0a844d66b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ebe46b2bcb2e4b7eb0300de0a844d66b = echarts.init(
#                     document.getElementById('ebe46b2bcb2e4b7eb0300de0a844d66b'), 'white', {renderer: 'canvas'});
#                 var option_ebe46b2bcb2e4b7eb0300de0a844d66b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u4e0a\u6d77\u5e02",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.0376568774345101
#                 ],
#                 [
#                     2011,
#                     0.047329276620871
#                 ],
#                 [
#                     2012,
#                     0.0533957720006144
#                 ],
#                 [
#                     2013,
#                     0.0514070656977042
#                 ],
#                 [
#                     2014,
#                     0.0573627696424518
#                 ],
#                 [
#                     2015,
#                     0.0568955394000219
#                 ],
#                 [
#                     2016,
#                     0.0511999147368542
#                 ],
#                 [
#                     2017,
#                     0.0625596879168599
#                 ],
#                 [
#                     2018,
#                     0.0661080826349105
#                 ],
#                 [
#                     2019,
#                     0.065974881722931
#                 ],
#                 [
#                     2020,
#                     0.0729530801202858
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#FF0000"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u6c5f\u82cf\u7701",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.0463661602737572
#                 ],
#                 [
#                     2011,
#                     0.0543057093902326
#                 ],
#                 [
#                     2012,
#                     0.0516694507144872
#                 ],
#                 [
#                     2013,
#                     0.0576044730866855
#                 ],
#                 [
#                     2014,
#                     0.0612445172984464
#                 ],
#                 [
#                     2015,
#                     0.0647408641973908
#                 ],
#                 [
#                     2016,
#                     0.0602880078115266
#                 ],
#                 [
#                     2017,
#                     0.0642139534335142
#                 ],
#                 [
#                     2018,
#                     0.0641163873218646
#                 ],
#                 [
#                     2019,
#                     0.0613756683061708
#                 ],
#                 [
#                     2020,
#                     0.066055526106225
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#00FF00"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u6d59\u6c5f\u7701",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.078207146587548
#                 ],
#                 [
#                     2011,
#                     0.0863199296364766
#                 ],
#                 [
#                     2012,
#                     0.079941011810577
#                 ],
#                 [
#                     2013,
#                     0.0891312717196978
#                 ],
#                 [
#                     2014,
#                     0.086100582341775
#                 ],
#                 [
#                     2015,
#                     0.100405863331966
#                 ],
#                 [
#                     2016,
#                     0.102159667967586
#                 ],
#                 [
#                     2017,
#                     0.104926970168004
#                 ],
#                 [
#                     2018,
#                     0.104597412890693
#                 ],
#                 [
#                     2019,
#                     0.110244009886556
#                 ],
#                 [
#                     2020,
#                     0.115360371468714
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#0000FF"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5b89\u5fbd\u7701",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.0717707460079732
#                 ],
#                 [
#                     2011,
#                     0.07239423521425
#                 ],
#                 [
#                     2012,
#                     0.0739648478013526
#                 ],
#                 [
#                     2013,
#                     0.0761111438467297
#                 ],
#                 [
#                     2014,
#                     0.0734046324225383
#                 ],

# %%
from pyecharts import options as opts
from pyecharts.charts import Line
from pyecharts.commons.utils import JsCode
import pandas as pd

# 创建折线图
line = Line().add_xaxis(green_en_["年份"])

# 添加数据
for i in range(1,len(parts)):
    part = parts[i]
    line.add_yaxis(
        series_name = part,
        y_axis = list(green_en_[part]),
        label_opts=opts.LabelOpts(is_show=False),
        yaxis_index=0,
#         linestyle_opts=opts.LineStyleOpts(color=color),  # Specify line color using linestyle_opts
        is_smooth=False,
    )  
line.set_global_opts(
    title_opts=opts.TitleOpts(title="Green Finance Development Index Over Time",pos_top='top', pos_left='center'),
    tooltip_opts=opts.TooltipOpts(trigger="axis"),
    xaxis_opts=opts.AxisOpts(name="Year", boundary_gap=False,min_=2010,max_=2020),
    yaxis_opts=opts.AxisOpts(name="Green Finance Development Index",type_="value",
#         axistick_opts=opts.AxisTickOpts(is_show=True),
#         splitline_opts=opts.SplitLineOpts(is_show=True),
                            ),
    legend_opts=opts.LegendOpts(pos_top="40"),# Position the legend outside the plot
)
line.render("green_finance_index_changjiangjjd.html")
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4a181405d47d4df8b7d6d8f729083763" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4a181405d47d4df8b7d6d8f729083763 = echarts.init(
#                     document.getElementById('4a181405d47d4df8b7d6d8f729083763'), 'white', {renderer: 'canvas'});
#                 var option_4a181405d47d4df8b7d6d8f729083763 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u4e0b\u6e38\u5730\u533a",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.16223018429581532
#                 ],
#                 [
#                     2011,
#                     0.1879549156475802
#                 ],
#                 [
#                     2012,
#                     0.1850062345256786
#                 ],
#                 [
#                     2013,
#                     0.1981428105040875
#                 ],
#                 [
#                     2014,
#                     0.2047078692826732
#                 ],
#                 [
#                     2015,
#                     0.22204226692937867
#                 ],
#                 [
#                     2016,
#                     0.2136475905159668
#                 ],
#                 [
#                     2017,
#                     0.23170061151837812
#                 ],
#                 [
#                     2018,
#                     0.23482188284746813
#                 ],
#                 [
#                     2019,
#                     0.2375945599156578
#                 ],
#                 [
#                     2020,
#                     0.2543689776952248
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u4e2d\u6e38\u5730\u533a",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.200934906384155
#                 ],
#                 [
#                     2011,
#                     0.1942044515648503
#                 ],
#                 [
#                     2012,
#                     0.20221155334691587
#                 ],
#                 [
#                     2013,
#                     0.21065603689297763
#                 ],
#                 [
#                     2014,
#                     0.20046401387809232
#                 ],
#                 [
#                     2015,
#                     0.20244591947413532
#                 ],
#                 [
#                     2016,
#                     0.2361860749650888
#                 ],
#                 [
#                     2017,
#                     0.2338748198802514
#                 ],
#                 [
#                     2018,
#                     0.22312733275197483
#                 ],
#                 [
#                     2019,
#                     0.27653142067733405
#                 ],
#                 [
#                     2020,
#                     0.2780397798535213
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u4e0a\u6e38\u5730\u533a",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.2768133749245026
#                 ],
#                 [
#                     2011,
#                     0.2710211940318281
#                 ],
#                 [
#                     2012,
#                     0.2514522195346149
#                 ],
#                 [
#                     2013,
#                     0.2293699144079975
#                 ],
#                 [
#                     2014,
#                     0.24947707166165048
#                 ],
#                 [
#                     2015,
#                     0.2322638143687035
#                 ],
#                 [
#                     2016,
#                     0.2272492288054097
#                 ],
#                 [
#                     2017,
#                     0.4250157965205908
#                 ],
#                 [
#                     2018,
#                     0.3919375776897645
#                 ],
#                 [
#                     2019,
#                     0.37558834530244734
#                 ],
#                 [
#                     2020,
#                     0.36443095048197194
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e0b\u6e38\u5730\u533a",
#                 "\u4e2d\u6e38\u5730\u533a",
#                 "\u4e0a\u6e38\u5730\u533a"
#             ],
#             "selected": {},
#             "show": true,
#             "top": "40",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7

# %% [markdown]
# # 能源优化

# %%
en_p = pd.read_excel("能源结构优化.xlsx",sheet_name = "能源结构优化指数")
en_p
# Out:
#       年份       上海市       江苏省       浙江省       安徽省       江西省       湖北省  \
# 0   2010  0.305431  0.203345  0.214997  0.090298  0.110904  0.128576
# 1   2011  0.312276  0.210394  0.224702  0.104975  0.122585  0.135192
# 2   2012  0.320669  0.220645  0.232092  0.116446  0.134713  0.143608
# 3   2013  0.330788  0.231824  0.243491  0.126772  0.144513  0.168688
# 4   2014  0.336462  0.240498  0.255565  0.135894  0.152296  0.177771
# 5   2015  0.344287  0.254222  0.260121  0.145143  0.162577  0.189634
# 6   2016  0.352156  0.263755  0.273232  0.160796  0.176262  0.198594
# 7   2017  0.353720  0.285450  0.286004  0.171905  0.189155  0.208450
# 8   2018  0.363667  0.302287  0.302115  0.193773  0.204938  0.218833
# 9   2019  0.368177  0.308305  0.312064  0.204362  0.213691  0.226370
# 10  2020  0.370712  0.314465  0.320255  0.216324  0.222788  0.233835
#
#          湖南省       重庆市       四川省       贵州省       云南省
# 0   0.112693  0.166072  0.147479  0.051889  0.074098
# 1   0.119011  0.174030  0.154129  0.059028  0.088391
# 2   0.128832  0.186602  0.157343  0.068136  0.101877
# 3   0.138678  0.213570  0.167613  0.078583  0.110047
# 4   0.146899  0.225498  0.179088  0.090823  0.131416
# 5   0.156886  0.251075  0.207564  0.104756  0.140816
# 6   0.165241  0.260314  0.220938  0.116059  0.148090
# 7   0.175129  0.268715  0.237653  0.131831  0.160697
# 8   0.189188  0.281488  0.254025  0.163691  0.169687
# 9   0.199017  0.291807  0.264554  0.173935  0.185735
# 10  0.206098  0.297328  0.272683  0.183739  0.194335

# %%
en_p_ =  pd.DataFrame() 
en_p_["年份"] = en_p["年份"]
en_p_["上游地区"] = en_p["重庆市"] +en_p["四川省"] + en_p["贵州省"] + en_p["云南省"]
en_p_["中游地区"] = en_p["安徽省"] +en_p["江西省"] + en_p["湖北省"]
en_p_["下游地区"] = en_p["上海市"] +en_p["江苏省"] + en_p["浙江省"]

# %%
en_p_.to_excel("en_data.xlsx")
en_p_
# Out:
#       年份      上游地区      中游地区      下游地区
# 0   2010  0.439538  0.329779  0.723773
# 1   2011  0.475579  0.362752  0.747372
# 2   2012  0.513958  0.394767  0.773406
# 3   2013  0.569813  0.439973  0.806103
# 4   2014  0.626825  0.465961  0.832526
# 5   2015  0.704211  0.497354  0.858630
# 6   2016  0.745401  0.535652  0.889143
# 7   2017  0.798895  0.569509  0.925174
# 8   2018  0.868891  0.617545  0.968070
# 9   2019  0.916030  0.644422  0.988546
# 10  2020  0.948085  0.672947  1.005432

# %%
import matplotlib.pyplot as plt  
import colorsys 

# Generate a list of color codes  
num_colors = len(names)  
colors = ["#FF0000", "#00FF00", "#0000FF", "#FFFF00",   "#00FFFF", "#FF00FF","#FFA500", "#800080",  "#A52A2A", "#808080","#000000", "#FFFFA"]
plt.figure(figsize=(12, 4))  
for i in range(1, len(names)): 
    color = colors[i-1]  
    plt.plot(en_p["年份"], en_p[names[i]], label=names[i], color=color)  
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Position the legend outside the plot  
plt.title('Energy structure optimization index Over Time')  
plt.xlabel('Year')  
plt.ylabel('Energy structure optimization indexx')  
plt.tight_layout()  
plt.show()

# %%
from pyecharts import options as opts
from pyecharts.charts import Line
from pyecharts.commons.utils import JsCode
import pandas as pd

# 创建折线图
line = Line().add_xaxis(en_p["年份"])
colors = ["#FF0000", "#00FF00", "#0000FF", "#FFFF00",   "#00FFFF", "#FF00FF","#FFA500", "#800080",  "#A52A2A", "#808080","#000000", "#FFFFA"]

# 添加数据
for i in range(1,12):
    name = names[i]
    color = colors[i-1]
    line.add_yaxis(
        series_name = name,
        y_axis = list(en_p[name]),
        label_opts=opts.LabelOpts(is_show=False),
        yaxis_index=0,
        linestyle_opts=opts.LineStyleOpts(color=color),  # Specify line color using linestyle_opts
        is_smooth=True,
    )  
line.set_global_opts(
    title_opts=opts.TitleOpts(title="Energy structure optimization index Over Time",pos_top='top', pos_left='center'),
    tooltip_opts=opts.TooltipOpts(trigger="axis"),
    xaxis_opts=opts.AxisOpts(name="Year", boundary_gap=False,min_=2010,max_=2020),
    yaxis_opts=opts.AxisOpts(name="Energy structure optimization index",type_="value",
#         axistick_opts=opts.AxisTickOpts(is_show=True),
#         splitline_opts=opts.SplitLineOpts(is_show=True),
                            ),
    legend_opts=opts.LegendOpts(pos_top="40"),# Position the legend outside the plot
)

line.render("Energy_structure_optimization_index.html")
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="218aa8d4694441dd99beb09c4e9f8237" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_218aa8d4694441dd99beb09c4e9f8237 = echarts.init(
#                     document.getElementById('218aa8d4694441dd99beb09c4e9f8237'), 'white', {renderer: 'canvas'});
#                 var option_218aa8d4694441dd99beb09c4e9f8237 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u4e0a\u6d77\u5e02",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.305431450991396
#                 ],
#                 [
#                     2011,
#                     0.312275763732527
#                 ],
#                 [
#                     2012,
#                     0.320668799104438
#                 ],
#                 [
#                     2013,
#                     0.330787635470851
#                 ],
#                 [
#                     2014,
#                     0.336462022174462
#                 ],
#                 [
#                     2015,
#                     0.344286572410174
#                 ],
#                 [
#                     2016,
#                     0.352156301434677
#                 ],
#                 [
#                     2017,
#                     0.353719913696885
#                 ],
#                 [
#                     2018,
#                     0.363667266473015
#                 ],
#                 [
#                     2019,
#                     0.36817747834272
#                 ],
#                 [
#                     2020,
#                     0.370711713171682
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#FF0000"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u6c5f\u82cf\u7701",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.203344787147643
#                 ],
#                 [
#                     2011,
#                     0.210393863763653
#                 ],
#                 [
#                     2012,
#                     0.22064457704957
#                 ],
#                 [
#                     2013,
#                     0.231824407290406
#                 ],
#                 [
#                     2014,
#                     0.240498187866432
#                 ],
#                 [
#                     2015,
#                     0.254222073774665
#                 ],
#                 [
#                     2016,
#                     0.263754788472472
#                 ],
#                 [
#                     2017,
#                     0.285449550384462
#                 ],
#                 [
#                     2018,
#                     0.302286764706149
#                 ],
#                 [
#                     2019,
#                     0.308304675187282
#                 ],
#                 [
#                     2020,
#                     0.314464934795819
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#00FF00"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u6d59\u6c5f\u7701",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.214996648447522
#                 ],
#                 [
#                     2011,
#                     0.224702353604414
#                 ],
#                 [
#                     2012,
#                     0.232092126733724
#                 ],
#                 [
#                     2013,
#                     0.243491092198104
#                 ],
#                 [
#                     2014,
#                     0.255565465850716
#                 ],
#                 [
#                     2015,
#                     0.260121318715909
#                 ],
#                 [
#                     2016,
#                     0.273231647546411
#                 ],
#                 [
#                     2017,
#                     0.286004418299941
#                 ],
#                 [
#                     2018,
#                     0.302115481437266
#                 ],
#                 [
#                     2019,
#                     0.312063809155456
#                 ],
#                 [
#                     2020,
#                     0.320254941095602
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#0000FF"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5b89\u5fbd\u7701",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.0902981694109644
#                 ],
#                 [
#                     2011,
#                     0.104974511031649
#                 ],
#                 [
#                     2012,
#                     0.116445721482605
#                 ],
#                 [
#                     2013,
#                     0.126772290092861
#                 ],
#                 [
#                     2014,
#                     0.1358936463629
#                 ],
#                 [
#                     2015,

# %%
import matplotlib.pyplot as plt  
import colorsys  

# Generate a list of color codes  
parts = en_p_.columns
plt.figure(figsize=(12, 4))  
for i in range(1, len(parts)): 
    plt.plot(en_p_["年份"], en_p_[parts[i]], label=parts[i])  
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Position the legend outside the plot  
plt.title('Energy structure optimization index Over Time')  
plt.xlabel('Year')  
plt.ylabel('Energy structure optimization index')  
plt.tight_layout()  
plt.show()

# %%
from pyecharts import options as opts
from pyecharts.charts import Line
from pyecharts.commons.utils import JsCode
import pandas as pd

# 创建折线图
line = Line().add_xaxis(en_p["年份"])
colors = ["#FF0000", "#00FF00", "#0000FF", "#FFFF00",   "#00FFFF", "#FF00FF","#FFA500", "#800080",  "#A52A2A", "#808080","#000000", "#FFFFA"]

# 添加数据
for i in range(1,12):
    name = names[i]
    color = colors[i-1]
    line.add_yaxis(
        series_name = name,
        y_axis = list(en_p[name]),
        label_opts=opts.LabelOpts(is_show=False),
        yaxis_index=0,
        linestyle_opts=opts.LineStyleOpts(color=color),  # Specify line color using linestyle_opts
        is_smooth=False,
    )  
line.set_global_opts(
    title_opts=opts.TitleOpts(title="Energy structure optimization index Over Time",pos_top='top', pos_left='center'),
    tooltip_opts=opts.TooltipOpts(trigger="axis"),
    xaxis_opts=opts.AxisOpts(name="Year", boundary_gap=False,min_=2010,max_=2020),
    yaxis_opts=opts.AxisOpts(name="Energy structure optimization index",type_="value",
#         axistick_opts=opts.AxisTickOpts(is_show=True),
#         splitline_opts=opts.SplitLineOpts(is_show=True),
                            ),
    legend_opts=opts.LegendOpts(pos_top="40"),# Position the legend outside the plot
)

line.render("Energy_structure_optimization_index.html2")
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b0a97f5f88054ea2a852b26e1f84f143" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b0a97f5f88054ea2a852b26e1f84f143 = echarts.init(
#                     document.getElementById('b0a97f5f88054ea2a852b26e1f84f143'), 'white', {renderer: 'canvas'});
#                 var option_b0a97f5f88054ea2a852b26e1f84f143 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u4e0a\u6d77\u5e02",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.305431450991396
#                 ],
#                 [
#                     2011,
#                     0.312275763732527
#                 ],
#                 [
#                     2012,
#                     0.320668799104438
#                 ],
#                 [
#                     2013,
#                     0.330787635470851
#                 ],
#                 [
#                     2014,
#                     0.336462022174462
#                 ],
#                 [
#                     2015,
#                     0.344286572410174
#                 ],
#                 [
#                     2016,
#                     0.352156301434677
#                 ],
#                 [
#                     2017,
#                     0.353719913696885
#                 ],
#                 [
#                     2018,
#                     0.363667266473015
#                 ],
#                 [
#                     2019,
#                     0.36817747834272
#                 ],
#                 [
#                     2020,
#                     0.370711713171682
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#FF0000"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u6c5f\u82cf\u7701",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.203344787147643
#                 ],
#                 [
#                     2011,
#                     0.210393863763653
#                 ],
#                 [
#                     2012,
#                     0.22064457704957
#                 ],
#                 [
#                     2013,
#                     0.231824407290406
#                 ],
#                 [
#                     2014,
#                     0.240498187866432
#                 ],
#                 [
#                     2015,
#                     0.254222073774665
#                 ],
#                 [
#                     2016,
#                     0.263754788472472
#                 ],
#                 [
#                     2017,
#                     0.285449550384462
#                 ],
#                 [
#                     2018,
#                     0.302286764706149
#                 ],
#                 [
#                     2019,
#                     0.308304675187282
#                 ],
#                 [
#                     2020,
#                     0.314464934795819
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#00FF00"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u6d59\u6c5f\u7701",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.214996648447522
#                 ],
#                 [
#                     2011,
#                     0.224702353604414
#                 ],
#                 [
#                     2012,
#                     0.232092126733724
#                 ],
#                 [
#                     2013,
#                     0.243491092198104
#                 ],
#                 [
#                     2014,
#                     0.255565465850716
#                 ],
#                 [
#                     2015,
#                     0.260121318715909
#                 ],
#                 [
#                     2016,
#                     0.273231647546411
#                 ],
#                 [
#                     2017,
#                     0.286004418299941
#                 ],
#                 [
#                     2018,
#                     0.302115481437266
#                 ],
#                 [
#                     2019,
#                     0.312063809155456
#                 ],
#                 [
#                     2020,
#                     0.320254941095602
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#0000FF"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5b89\u5fbd\u7701",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.0902981694109644
#                 ],
#                 [
#                     2011,
#                     0.104974511031649
#                 ],
#                 [
#                     2012,
#                     0.116445721482605
#                 ],
#                 [
#                     2013,
#                     0.126772290092861
#                 ],
#                 [
#                     2014,
#                     0.1358936463629
#                 ],
#                 [
#                     2

# %%
from pyecharts import options as opts
from pyecharts.charts import Line
from pyecharts.commons.utils import JsCode
import pandas as pd

# 创建折线图
line = Line().add_xaxis(en_p_["年份"])

# 添加数据
for i in range(1,len(parts)):
    part = parts[i]
    line.add_yaxis(
        series_name = part,
        y_axis = list(en_p_[part]),
        label_opts=opts.LabelOpts(is_show=False),
        yaxis_index=0,
#         linestyle_opts=opts.LineStyleOpts(color=color),  # Specify line color using linestyle_opts
        is_smooth=False,
    )  
line.set_global_opts(
    title_opts=opts.TitleOpts(title="Energy structure optimization index Over Time",pos_top='top', pos_left='center'),
    tooltip_opts=opts.TooltipOpts(trigger="axis"),
    xaxis_opts=opts.AxisOpts(name="Year", boundary_gap=False,min_=2010,max_=2020),
    yaxis_opts=opts.AxisOpts(name="Energy structure optimization index",type_="value",
#         axistick_opts=opts.AxisTickOpts(is_show=True),
#         splitline_opts=opts.SplitLineOpts(is_show=True),
                            ),
    legend_opts=opts.LegendOpts(pos_top="40"),# Position the legend outside the plot
)
line.render("Energy structure optimization index_changjiangjjd.html2")
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9da87b14de85472bbd12189400eb4dab" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9da87b14de85472bbd12189400eb4dab = echarts.init(
#                     document.getElementById('9da87b14de85472bbd12189400eb4dab'), 'white', {renderer: 'canvas'});
#                 var option_9da87b14de85472bbd12189400eb4dab = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u4e0b\u6e38\u5730\u533a",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.723772886586561
#                 ],
#                 [
#                     2011,
#                     0.747371981100594
#                 ],
#                 [
#                     2012,
#                     0.773405502887732
#                 ],
#                 [
#                     2013,
#                     0.806103134959361
#                 ],
#                 [
#                     2014,
#                     0.83252567589161
#                 ],
#                 [
#                     2015,
#                     0.858629964900748
#                 ],
#                 [
#                     2016,
#                     0.8891427374535601
#                 ],
#                 [
#                     2017,
#                     0.9251738823812881
#                 ],
#                 [
#                     2018,
#                     0.96806951261643
#                 ],
#                 [
#                     2019,
#                     0.988545962685458
#                 ],
#                 [
#                     2020,
#                     1.005431589063103
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u4e2d\u6e38\u5730\u533a",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.32977875644092336
#                 ],
#                 [
#                     2011,
#                     0.36275229485113397
#                 ],
#                 [
#                     2012,
#                     0.394767267485847
#                 ],
#                 [
#                     2013,
#                     0.439972673295975
#                 ],
#                 [
#                     2014,
#                     0.465961160698327
#                 ],
#                 [
#                     2015,
#                     0.497353966088207
#                 ],
#                 [
#                     2016,
#                     0.535651886315837
#                 ],
#                 [
#                     2017,
#                     0.569509494118548
#                 ],
#                 [
#                     2018,
#                     0.6175446602382639
#                 ],
#                 [
#                     2019,
#                     0.644422213015414
#                 ],
#                 [
#                     2020,
#                     0.672946750723151
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u4e0a\u6e38\u5730\u533a",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     0.43953783678796954
#                 ],
#                 [
#                     2011,
#                     0.47557889699719147
#                 ],
#                 [
#                     2012,
#                     0.5139578170392167
#                 ],
#                 [
#                     2013,
#                     0.5698134856164919
#                 ],
#                 [
#                     2014,
#                     0.6268252944800324
#                 ],
#                 [
#                     2015,
#                     0.704211309989758
#                 ],
#                 [
#                     2016,
#                     0.74540074582243
#                 ],
#                 [
#                     2017,
#                     0.7988951890837329
#                 ],
#                 [
#                     2018,
#                     0.8688911829825319
#                 ],
#                 [
#                     2019,
#                     0.9160304408605708
#                 ],
#                 [
#                     2020,
#                     0.9480852899718241
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e0b\u6e38\u5730\u533a",
#                 "\u4e2d\u6e38\u5730\u533a",
#                 "\u4e0a\u6e38\u5730\u533a"
#             ],
#             "selected": {},
#             "show": true,
#             "top": "40",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonG

# %% [markdown]
# # 技术进步

# %%
# te_ad = pd.read_excel("技术进步指数.xlsx",sheet_name = "综合评分")
te_ad = pd.read_excel("技术进步.xlsx",sheet_name = "技术进步指数")
te_ad
# Out:
#       年份       上海市       江苏省       浙江省       安徽省       江西省       湖北省  \
# 0   2010  0.140690  0.201167  0.078245  0.030367  0.022648  0.046208
# 1   2011  0.161507  0.292779  0.125096  0.047209  0.029987  0.076147
# 2   2012  0.186831  0.351535  0.159302  0.054915  0.034008  0.104173
# 3   2013  0.205493  0.405989  0.178100  0.070292  0.041537  0.142048
# 4   2014  0.228873  0.453864  0.203903  0.091770  0.050895  0.174436
# 5   2015  0.241085  0.469441  0.230291  0.110038  0.056249  0.213341
# 6   2016  0.256712  0.523868  0.265953  0.124975  0.056403  0.242623
# 7   2017  0.267724  0.567353  0.300756  0.149795  0.071354  0.268958
# 8   2018  0.311893  0.650901  0.382542  0.171035  0.095122  0.318372
# 9   2019  0.357893  0.800006  0.460595  0.201207  0.120897  0.393976
# 10  2020  0.412217  1.010000  0.584677  0.264234  0.153992  0.440033
#
#          湖南省       重庆市       四川省       贵州省       云南省  0.0104391513836988
# 0   0.024525  0.027267  0.044949  0.020303  0.010439                1.01
# 1   0.038336  0.029264  0.057224  0.020008  0.014135                 NaN
# 2   0.042717  0.030091  0.074728  0.027147  0.020707                 NaN
# 3   0.059022  0.037915  0.099673  0.032872  0.019310                 NaN
# 4   0.071411  0.051350  0.122177  0.035633  0.021352                 NaN
# 5   0.094351  0.050565  0.139295  0.031236  0.022356                 NaN
# 6   0.100120  0.070488  0.163180  0.031121  0.023189                 NaN
# 7   0.119165  0.064305  0.194605  0.043952  0.027643                 NaN
# 8   0.140951  0.097191  0.296837  0.058287  0.029142                 NaN
# 9   0.169284  0.083021  0.322896  0.064967  0.029550                 NaN
# 10  0.228582  0.101022  0.358008  0.074561  0.029168                 NaN

# %%
# from pyecharts.charts import Map  # 注意这里与老版本pyecharts调用的区别
# from pyecharts import options as opts
# import random
# country = ['China', 'Canada', 'France', 'Japan', 'Russia', 'USA']
# data_world = [(i, random.randint(100, 200)) for i in country]
# world = (
#     Map()
#     .add('', # 此处没取名，所以空着
#     	data_world, # 数据
#     	'world') # 地图类型
#     .set_global_opts(
#         title_opts=opts.TitleOpts(title='World Map'),
#         visualmap_opts=opts.VisualMapOpts(
#             max_=200,
#             min_=100,
#             is_piecewise=True)  # 定义图例为分段型，默认为连续的图例
#     )
#     .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
#     .render(path='世界地图.html')
# )

# %%
from pyecharts.charts import Map  # 注意这里与老版本pyecharts调用的区别
from pyecharts import options as opts
import random
province = ['上海市', '江苏省', '浙江省', '安徽省', '江西省', '湖北省', '湖南省', '重庆市', '四川省', '贵州省', '云南省']
data_province = [(i, list(te_ad[i])) for i in province]
# print(data_province)
china_province = (
    Map()
    .add('', data_province, 'china')
    .set_global_opts(
        title_opts=opts.TitleOpts(title='Provinces of China'),
        visualmap_opts=opts.VisualMapOpts(
            min_=0.01,
            max_=1.1,
            is_piecewise=True,
        range_color=['#E0EEE0', '#006400'])
    )
)
# china_province.render(path='china_province.html')
china_province.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="14e83f68c65d457488c59324ea1454cd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_14e83f68c65d457488c59324ea1454cd = echarts.init(
#                     document.getElementById('14e83f68c65d457488c59324ea1454cd'), 'white', {renderer: 'canvas'});
#                 var option_14e83f68c65d457488c59324ea1454cd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "map": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": [
#                         0.140690039819595,
#                         0.161506997205439,
#                         0.186830563867999,
#                         0.205492914118586,
#                         0.22887254555286,
#                         0.241084911734855,
#                         0.256711787828083,
#                         0.267724018491361,
#                         0.311893195755631,
#                         0.35789285631895,
#                         0.412217143366775
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf\u7701",
#                     "value": [
#                         0.20116678314259,
#                         0.292778903983146,
#                         0.351535048382865,
#                         0.405988919733223,
#                         0.453864017358703,
#                         0.46944067159875,
#                         0.523867865033932,
#                         0.567353102516354,
#                         0.650901173628013,
#                         0.800005620413802,
#                         1.01
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f\u7701",
#                     "value": [
#                         0.0782448043986453,
#                         0.12509615563133,
#                         0.159301584479029,
#                         0.17809977740351,
#                         0.203903099151713,
#                         0.230290986791498,
#                         0.265953294708987,
#                         0.300755526552354,
#                         0.382542193937471,
#                         0.460594708383741,
#                         0.584676945653064
#                     ]
#                 },
#                 {
#                     "name": "\u5b89\u5fbd\u7701",
#                     "value": [
#                         0.0303670449302118,
#                         0.0472091879400025,
#                         0.054914823641117,
#                         0.0702924429955712,
#                         0.0917695540498457,
#                         0.110037975914153,
#                         0.124974730584133,
#                         0.149794644657181,
#                         0.171035250653449,
#                         0.201206636386071,
#                         0.264233748420248
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f\u7701",
#                     "value": [
#                         0.0226475095102109,
#                         0.029987460777589,
#                         0.0340081639606902,
#                         0.0415367015817489,
#                         0.0508951032381333,
#                         0.0562485098696412,
#                         0.056402928588176,
#                         0.0713541869610886,
#                         0.0951224375263022,
#                         0.120896662130532,
#                         0.153991989110344
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5317\u7701",
#                     "value": [
#                         0.0462084882027722,
#                         0.0761468888812834,
#                         0.104172807681127,
#                         0.142047858352483,
#                         0.174436444843723,
#                         0.21334129660279,
#                         0.242622592915064,
#                         0.268957710045369,
#                         0.31837161308337,
#                         0.393975632627747,
#                         0.44003323456608
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357\u7701",
#                     "value": [
#                         0.0245252460096956,
#                         0.0383356034761168,
#                         0.042716719061177,
#                         0.0590223923203479,
#                         0.0714112616359222,
#                         0.0943514875393548,
#                         0.100119879780476,
#                         0.119164802425957,
#                         0.14095083647053,
#                         0.169283620799443,
#                         0.228581887712601
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86\u5e02",
#                     "value": [
#                         0.0272668827382483,
#                         0.0292639336169335,
#                         0.0300913058289655,
#                         0.037914689762041,
#                         0.0513499062741295,
#                         0.0505647782830466,
#                         0.0704878302853022,
#                         0.0643052018624767,
#                         0.097190717175156,
#                         0.0830206641584844,
#                         0.101021882849194
#                     ]
#                 },
#                 {
#                     "name": "\u56db\u5ddd\u7701",
#                     "value": [
#                         0.0449489326255156,
#                         0.0572244890181331,
#                         0.0747284370684692,
#                         0.0996734597291384,
#                         0.122176597123861,
#                         0.139295011875245,
#                         0.1631803585115,
#                         0.19460456643141,
#                         0.296837205462836,
#                         0.322895794992203,
#                         0.358007997127724
#                     ]
#                 },
#                 {
#                     "name": "\u8d35\u5dde\u7701",
#                     "value": [
#                         0.0203027932351829,
#                         0.020007501075164,
#                         0.0271465558281474,
#                         0.0328717307617139,
#                         0.0356330281855378,
#                         0.0312362562229054,
#                         0.0311213384256619,
#                         0.04395187993402,
#                         0.0582867032799214,
#                         0.0649668036585827,
#                         0.0745609752923097
#                     ]
#                 },
#                 {
#                     "name": "\u4e91\u5357\u7701",
#                     "value": [
#                         0.0104391513836988,
#                         0.0141353780883609,
#                         0.0207074789818084,
#                         0.01930987281431,
#                         0.0213517936397154,
#                         0.0223559745011737,
#                         0.023189164145325,
#                         0.0276432468960757,
#                         0.0291424229064525,
#                         0.0295502016957289,

# %%
from pyecharts.charts import Map  # 注意这里与老版本pyecharts调用的区别
from pyecharts import options as opts
import random
province = ['上海市', '江苏省', '浙江省', '安徽省', '江西省', '湖北省', '湖南省', '重庆市', '四川省', '贵州省', '云南省']
data_province = [(i, list(te_ad[i])) for i in province]
# print(data_province)
china_province = (
    Map()
    .add('', data_province, 'china')
    .set_global_opts(
        title_opts=opts.TitleOpts(title='Provinces of China'),
        visualmap_opts=opts.VisualMapOpts(
            min_=0.01,
            max_=1.1,
            is_piecewise=True,
        range_color=['#C0FF3E', '#0E9A34'])
    )
)
# china_province.render(path='china_province.html')
china_province.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="7d929e4439f143cebbca1d8adabe97cc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_7d929e4439f143cebbca1d8adabe97cc = echarts.init(
#                     document.getElementById('7d929e4439f143cebbca1d8adabe97cc'), 'white', {renderer: 'canvas'});
#                 var option_7d929e4439f143cebbca1d8adabe97cc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "map": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": [
#                         0.140690039819595,
#                         0.161506997205439,
#                         0.186830563867999,
#                         0.205492914118586,
#                         0.22887254555286,
#                         0.241084911734855,
#                         0.256711787828083,
#                         0.267724018491361,
#                         0.311893195755631,
#                         0.35789285631895,
#                         0.412217143366775
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf\u7701",
#                     "value": [
#                         0.20116678314259,
#                         0.292778903983146,
#                         0.351535048382865,
#                         0.405988919733223,
#                         0.453864017358703,
#                         0.46944067159875,
#                         0.523867865033932,
#                         0.567353102516354,
#                         0.650901173628013,
#                         0.800005620413802,
#                         1.01
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f\u7701",
#                     "value": [
#                         0.0782448043986453,
#                         0.12509615563133,
#                         0.159301584479029,
#                         0.17809977740351,
#                         0.203903099151713,
#                         0.230290986791498,
#                         0.265953294708987,
#                         0.300755526552354,
#                         0.382542193937471,
#                         0.460594708383741,
#                         0.584676945653064
#                     ]
#                 },
#                 {
#                     "name": "\u5b89\u5fbd\u7701",
#                     "value": [
#                         0.0303670449302118,
#                         0.0472091879400025,
#                         0.054914823641117,
#                         0.0702924429955712,
#                         0.0917695540498457,
#                         0.110037975914153,
#                         0.124974730584133,
#                         0.149794644657181,
#                         0.171035250653449,
#                         0.201206636386071,
#                         0.264233748420248
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f\u7701",
#                     "value": [
#                         0.0226475095102109,
#                         0.029987460777589,
#                         0.0340081639606902,
#                         0.0415367015817489,
#                         0.0508951032381333,
#                         0.0562485098696412,
#                         0.056402928588176,
#                         0.0713541869610886,
#                         0.0951224375263022,
#                         0.120896662130532,
#                         0.153991989110344
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5317\u7701",
#                     "value": [
#                         0.0462084882027722,
#                         0.0761468888812834,
#                         0.104172807681127,
#                         0.142047858352483,
#                         0.174436444843723,
#                         0.21334129660279,
#                         0.242622592915064,
#                         0.268957710045369,
#                         0.31837161308337,
#                         0.393975632627747,
#                         0.44003323456608
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357\u7701",
#                     "value": [
#                         0.0245252460096956,
#                         0.0383356034761168,
#                         0.042716719061177,
#                         0.0590223923203479,
#                         0.0714112616359222,
#                         0.0943514875393548,
#                         0.100119879780476,
#                         0.119164802425957,
#                         0.14095083647053,
#                         0.169283620799443,
#                         0.228581887712601
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86\u5e02",
#                     "value": [
#                         0.0272668827382483,
#                         0.0292639336169335,
#                         0.0300913058289655,
#                         0.037914689762041,
#                         0.0513499062741295,
#                         0.0505647782830466,
#                         0.0704878302853022,
#                         0.0643052018624767,
#                         0.097190717175156,
#                         0.0830206641584844,
#                         0.101021882849194
#                     ]
#                 },
#                 {
#                     "name": "\u56db\u5ddd\u7701",
#                     "value": [
#                         0.0449489326255156,
#                         0.0572244890181331,
#                         0.0747284370684692,
#                         0.0996734597291384,
#                         0.122176597123861,
#                         0.139295011875245,
#                         0.1631803585115,
#                         0.19460456643141,
#                         0.296837205462836,
#                         0.322895794992203,
#                         0.358007997127724
#                     ]
#                 },
#                 {
#                     "name": "\u8d35\u5dde\u7701",
#                     "value": [
#                         0.0203027932351829,
#                         0.020007501075164,
#                         0.0271465558281474,
#                         0.0328717307617139,
#                         0.0356330281855378,
#                         0.0312362562229054,
#                         0.0311213384256619,
#                         0.04395187993402,
#                         0.0582867032799214,
#                         0.0649668036585827,
#                         0.0745609752923097
#                     ]
#                 },
#                 {
#                     "name": "\u4e91\u5357\u7701",
#                     "value": [
#                         0.0104391513836988,
#                         0.0141353780883609,
#                         0.0207074789818084,
#                         0.01930987281431,
#                         0.0213517936397154,
#                         0.0223559745011737,
#                         0.023189164145325,
#                         0.0276432468960757,
#                         0.0291424229064525,
#                         0.0295502016957289,

# %%
from pyecharts.charts import Map
from pyecharts import options as opts
import random

province = ['上海市', '江苏省', '浙江省', '安徽省', '江西省', '湖北省', '湖南省', '重庆市', '四川省', '贵州省', '云南省']

# Assuming te_ad is your data source
# data_province should only contain provinces with non-zero values
data_province = [(i, list(te_ad[i])) for i in province if any(val != 0 for val in te_ad[i])]

china_province = (
    Map()
    .add('', data_province, 'china')
    .set_global_opts(
        title_opts=opts.TitleOpts(title='Provinces of China'),
        visualmap_opts=opts.VisualMapOpts(
            min_=0.01,
            max_=1.1,
            is_piecewise=True,
            range_color=['#C0FF3E', '#0E9A34']
        )
    )
)
china_province.render(path='china_province.html')
china_province.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="0487eda4326c45699e6745ba72827881" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_0487eda4326c45699e6745ba72827881 = echarts.init(
#                     document.getElementById('0487eda4326c45699e6745ba72827881'), 'white', {renderer: 'canvas'});
#                 var option_0487eda4326c45699e6745ba72827881 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "map": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": [
#                         0.140690039819595,
#                         0.161506997205439,
#                         0.186830563867999,
#                         0.205492914118586,
#                         0.22887254555286,
#                         0.241084911734855,
#                         0.256711787828083,
#                         0.267724018491361,
#                         0.311893195755631,
#                         0.35789285631895,
#                         0.412217143366775
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf\u7701",
#                     "value": [
#                         0.20116678314259,
#                         0.292778903983146,
#                         0.351535048382865,
#                         0.405988919733223,
#                         0.453864017358703,
#                         0.46944067159875,
#                         0.523867865033932,
#                         0.567353102516354,
#                         0.650901173628013,
#                         0.800005620413802,
#                         1.01
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f\u7701",
#                     "value": [
#                         0.0782448043986453,
#                         0.12509615563133,
#                         0.159301584479029,
#                         0.17809977740351,
#                         0.203903099151713,
#                         0.230290986791498,
#                         0.265953294708987,
#                         0.300755526552354,
#                         0.382542193937471,
#                         0.460594708383741,
#                         0.584676945653064
#                     ]
#                 },
#                 {
#                     "name": "\u5b89\u5fbd\u7701",
#                     "value": [
#                         0.0303670449302118,
#                         0.0472091879400025,
#                         0.054914823641117,
#                         0.0702924429955712,
#                         0.0917695540498457,
#                         0.110037975914153,
#                         0.124974730584133,
#                         0.149794644657181,
#                         0.171035250653449,
#                         0.201206636386071,
#                         0.264233748420248
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f\u7701",
#                     "value": [
#                         0.0226475095102109,
#                         0.029987460777589,
#                         0.0340081639606902,
#                         0.0415367015817489,
#                         0.0508951032381333,
#                         0.0562485098696412,
#                         0.056402928588176,
#                         0.0713541869610886,
#                         0.0951224375263022,
#                         0.120896662130532,
#                         0.153991989110344
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5317\u7701",
#                     "value": [
#                         0.0462084882027722,
#                         0.0761468888812834,
#                         0.104172807681127,
#                         0.142047858352483,
#                         0.174436444843723,
#                         0.21334129660279,
#                         0.242622592915064,
#                         0.268957710045369,
#                         0.31837161308337,
#                         0.393975632627747,
#                         0.44003323456608
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357\u7701",
#                     "value": [
#                         0.0245252460096956,
#                         0.0383356034761168,
#                         0.042716719061177,
#                         0.0590223923203479,
#                         0.0714112616359222,
#                         0.0943514875393548,
#                         0.100119879780476,
#                         0.119164802425957,
#                         0.14095083647053,
#                         0.169283620799443,
#                         0.228581887712601
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86\u5e02",
#                     "value": [
#                         0.0272668827382483,
#                         0.0292639336169335,
#                         0.0300913058289655,
#                         0.037914689762041,
#                         0.0513499062741295,
#                         0.0505647782830466,
#                         0.0704878302853022,
#                         0.0643052018624767,
#                         0.097190717175156,
#                         0.0830206641584844,
#                         0.101021882849194
#                     ]
#                 },
#                 {
#                     "name": "\u56db\u5ddd\u7701",
#                     "value": [
#                         0.0449489326255156,
#                         0.0572244890181331,
#                         0.0747284370684692,
#                         0.0996734597291384,
#                         0.122176597123861,
#                         0.139295011875245,
#                         0.1631803585115,
#                         0.19460456643141,
#                         0.296837205462836,
#                         0.322895794992203,
#                         0.358007997127724
#                     ]
#                 },
#                 {
#                     "name": "\u8d35\u5dde\u7701",
#                     "value": [
#                         0.0203027932351829,
#                         0.020007501075164,
#                         0.0271465558281474,
#                         0.0328717307617139,
#                         0.0356330281855378,
#                         0.0312362562229054,
#                         0.0311213384256619,
#                         0.04395187993402,
#                         0.0582867032799214,
#                         0.0649668036585827,
#                         0.0745609752923097
#                     ]
#                 },
#                 {
#                     "name": "\u4e91\u5357\u7701",
#                     "value": [
#                         0.0104391513836988,
#                         0.0141353780883609,
#                         0.0207074789818084,
#                         0.01930987281431,
#                         0.0213517936397154,
#                         0.0223559745011737,
#                         0.023189164145325,
#                         0.0276432468960757,
#                         0.0291424229064525,
#                         0.0295502016957289,
